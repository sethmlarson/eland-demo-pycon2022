# %% [markdown]
# # 👋 Welcome to the PyCon 2022 Demo of Eland!
#
# The Elasticsearch cluster being used for this demo is [hosted on Elastic Cloud](https://cloud.elastic.co)
# and this Jupyter Notebook is [hosted by Binder](https://mybinder.org).
#
# ## Resources
#
# ### ➤ Notebook: [github.com/sethmlarson/eland-demo-pycon2022](https://github.com/sethmlarson/eland-demo-pycon2022)
# ### ➤ [Eland Documentation (eland.readthedocs.io)](https://eland.readthedocs.io)
# ### ➤ [Eland Source Code on GitHub](https://github.com/elastic/eland)
# ### ➤ [Jupyter Notebook Source Code](https://github.com/sethmlarson/eland-binder-demo)
# ### ➤ [Tweets indexed by Tweepy](https://www.tweepy.org)
#
# ## Installing
#
# Eland is available on [PyPI](https://pypi.org/project/eland) with Pip:
#
# ```
# $ python -m pip install eland
# ```
#
# and on [Conda Forge](https://anaconda.org/conda-forge/eland):
#
# ```
# $ conda install -c conda-forge eland
# ```
#
# ## Getting Started
#
# This Jupyter Notebook works like any other Jupyter Notebook, you can simply browse the already completed results or you can try things out yourself by modifying a code block and hitting "Run". The Elasticsearch cluster in Elastic Cloud will respond with new results.
#
# If you're unfamiliar with Jupyter Notebooks there's a [quickstart guide available](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook).

# %%
import pandas as pd
import matplotlib.pyplot as plt

import eland as ed
from elasticsearch import Elasticsearch

# %% [markdown]
# ## Creating a Connection to Elasticsearch
#
# Our Elasticsearch instance is running in [Elastic Cloud](https://www.elastic.co/cloud)
# and uses an [API Key](https://www.elastic.co/guide/en/kibana/master/api-keys.html)
# configured to be read only with access to the `tweets` index.

# %%
es = Elasticsearch(
  cloud_id="PyCon_US_2022_Demo:dXMtY2VudHJhbDEuZ2NwLmNsb3VkLmVzLmlvJDY5N2MyMjBiMzZlZDRlNmQ5YTNkYmQ2NGYzMDFiZjY5JGQ5MTk0OTgzMDQ1MzQwZDQ5ZGM3N2U0NGQ4NmRjZjZh",
  api_key=("DS18dYAB3ckAcsHiHYu7", "qBkMFMpsQ4WsxaBxvwOdfg")
)

# %% [markdown]
# Now we can create an [`eland.DataFrame`](https://eland.readthedocs.io/en/latest/reference/dataframe.html) from the `tweets` index:

# %%
df = ed.DataFrame(
  es, es_index_pattern="tweets",
)

# %% [markdown]
# ## Exploring the Dataset
#
# You can explore a DataFrame in Eland the same way you would a Pandas DataFrame. If we just look at the `df` instance we receive:

# %%
df
# Out:
#                                    @timestamp           author  \
# 1519300067898716161 2022-04-27 12:58:58+00:00         iris9112
# 1519274909377175552 2022-04-27 11:18:59+00:00     pythonairobi
# 1519174404588113925 2022-04-27 04:39:37+00:00        ajpinedam
# 1519172769467932673 2022-04-27 04:33:07+00:00    existenzkampf
# 1519172467142520833 2022-04-27 04:31:55+00:00         ggoddard
# ...                                       ...              ...
# 1519469871486013440 2022-04-28 00:13:42+00:00       AlSweigart
# 1519669465100730370 2022-04-28 13:26:49+00:00       driscollis
# 1519669621531492352 2022-04-28 13:27:26+00:00       ponderings
# 1519670995329638403 2022-04-28 13:32:54+00:00  ChristianHeimes
# 1519671502743908352 2022-04-28 13:34:55+00:00       avikumart_
#
#                                                                                                                                                                                                                                                                                                    content  \
# 1519300067898716161                                                                                                                                                                            Check out this #Python tutorial: How to Get the Most Out of PyCon US by @realpython https://t.co/FPIZ6WhOK8
# 1519274909377175552                                                                                                                           Ticketing Updates:\n\n✅ Ticket Sales for PyCON KE will increase to KES 2,000 on Friday 29th April\n\n✅ Ticket Sales Closes on Monday https://t.co/D9WNLSurQE
# 1519174404588113925                                                                                                                                                                                                   @treyhunner @jesstemporal @pycon @KojoIdrissa @melaniearbor I am flying tomorrow!! 🎉
# 1519172769467932673                                                                                                                                                                                                                                                         @billpollock @pycon Enjoy SLC!
# 1519172467142520833  An attempt at a complete brewery list for those attending #PyCon in SLC: @TFamilybrewing @properbrewingco @shadesbrewing @FisherBrewingCo @GridCityBeer @RedRockBrewing @LevelCrossingBC @squattersbeers @wasatchbeers @EpicBrewingSLC @UintaBrewing @bewilderbeer @rohabrewing (1/2)
# ...                                                                                                                                                                                                                                                                                                    ...
# 1519469871486013440                                                                                                                                                                                                                          So anyone doing anything for dinner at #PyCon in SLC tonight?
# 1519669465100730370                                                                                                                                  Let's take the way back machine to 2009 when you could purchase exclusive @pycon merch at #PyCon such as this awesome hoodie! https://t.co/etRbrGZQ4a
# 1519669621531492352                                                                                                                                                                                                                                           @driscollis @CircuitPython @pycon Which con?
# 1519670995329638403                                                                                                                                                                             Good morning #PyCon #PyConUS2022\nIt's a beautiful morning here in Salt Lake City. https://t.co/McdvTamsrr
# 1519671502743908352                                                                                                                                                                                                                                       @driscollis @CircuitPython @pycon have fun Mike👍
#
#                     language  likes  replies  retweets             tweet_id
# 1519300067898716161       en      0        0         0  1519300067898716161
# 1519274909377175552       en      6        0         4  1519274909377175552
# 1519174404588113925       en      3        1         0  1519174404588113925
# 1519172769467932673       en      2        0         0  1519172769467932673
# 1519172467142520833       en      1        2         0  1519172467142520833
# ...                      ...    ...      ...       ...                  ...
# 1519469871486013440       en      3        0         0  1519469871486013440
# 1519669465100730370       en     22        0         0  1519669465100730370
# 1519669621531492352       en      1        1         0  1519669621531492352
# 1519670995329638403       en     23        1         0  1519670995329638403
# 1519671502743908352       en      1        1         0  1519671502743908352
#
# [1232 rows x 8 columns]

# %% [markdown]
# Looks just like a pandas DataFrame! Let's look closer:

# %%
df.info()
# Out:
# <class 'eland.dataframe.DataFrame'>
# Index: 1232 entries, 1518999040884543490 to 1519469871486013440
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   @timestamp  1232 non-null   datetime64[ns]
#  1   author      1232 non-null   object
#  2   content     1232 non-null   object
#  3   language    1232 non-null   object
#  4   likes       1232 non-null   int64
#  5   replies     1232 non-null   int64
#  6   retweets    1232 non-null   int64
#  7   tweet_id    1232 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 64.000 bytes
# Elasticsearch storage usage: 831.189 KB

# %% [markdown]
# ## Window into Elasticsearch
#
# When data updates in Elasticsearch the dataframe is automatically updated.

# %%
df.shape
# Out:
# (1232, 8)

# %% [markdown]
# ## Mapping Data Types from Elasticsearch to Pandas
#
# Eland maps [Elasticsearch Field datatypes](https://www.elastic.co/guide/en/elasticsearch/reference/current/mapping-types.html) into [datatypes understood by pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#basics-dtypes).
#
# We can see the mapping between the two dtypes nicely by joining the
# traditional `DataFrame.dtypes` series with `DataFrame.es_dtypes` to show
# what types are being used within Elasticsearch:

# %%
pd_dtypes = df.dtypes.rename("pandas")
es_dtypes = df.es_dtypes.rename("Elasticsearch")

pd_dtypes.to_frame().join(es_dtypes)
# Out:
#                     pandas Elasticsearch
# @timestamp  datetime64[ns]          date
# author              object       keyword
# content             object          text
# language            object       keyword
# likes                int64          long
# replies              int64          long
# retweets             int64          long
# tweet_id            object       keyword

# %% [markdown]
# ## Retrieving Data from Elasticsearch
#
# Here we ask for the first 5 entries via the `head()` method. Data still hasn't been permanently pulled out of Elasticsearch yet, to do that we use `to_pandas()`, but be careful, we don't want to dump all the data from our cluster all at once.

# %%
# Still an Eland DataFrame:
head_df = df.head(5)
print(type(head_df))

head_df
# Out:
# <class 'eland.dataframe.DataFrame'>
#                                    @timestamp         author  \
# 1519300067898716161 2022-04-27 12:58:58+00:00       iris9112
# 1519274909377175552 2022-04-27 11:18:59+00:00   pythonairobi
# 1519174404588113925 2022-04-27 04:39:37+00:00      ajpinedam
# 1519172769467932673 2022-04-27 04:33:07+00:00  existenzkampf
# 1519172467142520833 2022-04-27 04:31:55+00:00       ggoddard
#
#                                                                                                                                                                                                                                                                                                    content  \
# 1519300067898716161                                                                                                                                                                            Check out this #Python tutorial: How to Get the Most Out of PyCon US by @realpython https://t.co/FPIZ6WhOK8
# 1519274909377175552                                                                                                                           Ticketing Updates:\n\n✅ Ticket Sales for PyCON KE will increase to KES 2,000 on Friday 29th April\n\n✅ Ticket Sales Closes on Monday https://t.co/D9WNLSurQE
# 1519174404588113925                                                                                                                                                                                                   @treyhunner @jesstemporal @pycon @KojoIdrissa @melaniearbor I am flying tomorrow!! 🎉
# 1519172769467932673                                                                                                                                                                                                                                                         @billpollock @pycon Enjoy SLC!
# 1519172467142520833  An attempt at a complete brewery list for those attending #PyCon in SLC: @TFamilybrewing @properbrewingco @shadesbrewing @FisherBrewingCo @GridCityBeer @RedRockBrewing @LevelCrossingBC @squattersbeers @wasatchbeers @EpicBrewingSLC @UintaBrewing @bewilderbeer @rohabrewing (1/2)
#
#                     language  likes  replies  retweets             tweet_id
# 1519300067898716161       en      0        0         0  1519300067898716161
# 1519274909377175552       en      6        0         4  1519274909377175552
# 1519174404588113925       en      3        1         0  1519174404588113925
# 1519172769467932673       en      2        0         0  1519172769467932673
# 1519172467142520833       en      1        2         0  1519172467142520833
#
# [5 rows x 8 columns]

# %%
# Now we're a pandas DataFrame:
pd_df = head_df.to_pandas()
print(type(pd_df))

pd_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                    @timestamp         author  \
# 1519300067898716161 2022-04-27 12:58:58+00:00       iris9112
# 1519274909377175552 2022-04-27 11:18:59+00:00   pythonairobi
# 1519174404588113925 2022-04-27 04:39:37+00:00      ajpinedam
# 1519172769467932673 2022-04-27 04:33:07+00:00  existenzkampf
# 1519172467142520833 2022-04-27 04:31:55+00:00       ggoddard
#
#                                                                content  \
# 1519300067898716161  Check out this #Python tutorial: How to Get th...
# 1519274909377175552  Ticketing Updates:\n\n✅ Ticket Sales for PyCON...
# 1519174404588113925  @treyhunner @jesstemporal @pycon @KojoIdrissa ...
# 1519172769467932673                     @billpollock @pycon Enjoy SLC!
# 1519172467142520833  An attempt at a complete brewery list for thos...
#
#                     language  likes  replies  retweets             tweet_id
# 1519300067898716161       en      0        0         0  1519300067898716161
# 1519274909377175552       en      6        0         4  1519274909377175552
# 1519174404588113925       en      3        1         0  1519174404588113925
# 1519172769467932673       en      2        0         0  1519172769467932673
# 1519172467142520833       en      1        2         0  1519172467142520833

# %% [markdown]
# ## Filtering Rows in a Data Frame
#
# You can apply filters to our data frame in the same way that you can with Pandas. Here we're filtering for rows which are in the 'Staten Island' borough, with a 'True' `critical_flag`, and a `grade` that's either 'C' or 'N'.
# Then we filter the data frame to only include the columns `name`, `boro`, `critical_flag`, and `grade`:

# %%
from datetime import datetime

today = datetime.now().replace(hour=0, minute=0, second=0)

df[
  (df["@timestamp"] >= today)
  & (df.author != "pycon")
].filter(
  ["@timestamp", "author", "content"]
).to_pandas().sort_values("@timestamp").head(10)
# Out:
#                                    @timestamp           author  \
# 1519828816855715840 2022-04-29 00:00:01+00:00  Auth0Ambassador
# 1519829570811318274 2022-04-29 00:03:01+00:00      Boldstartvc
# 1519830536855773186 2022-04-29 00:06:51+00:00     andrewgodwin
# 1519830688760877056 2022-04-29 00:07:27+00:00     __biancarosa
# 1519831135164899330 2022-04-29 00:09:14+00:00  ThatEliGuyatOCI
# 1519831372138835969 2022-04-29 00:10:10+00:00      anvil_works
# 1519832200702619648 2022-04-29 00:13:28+00:00  StoneVaughanLaw
# 1519832577959514114 2022-04-29 00:14:58+00:00  PandaConstantin
# 1519832867898937345 2022-04-29 00:16:07+00:00            herlo
# 1519834573076541440 2022-04-29 00:22:54+00:00           jshell
#
#                                                                content
# 1519828816855715840  Going to @pycon US this week?!\n\n👋Stop by and...
# 1519829570811318274  This is so great! Look for @SlimDevOps at @pyc...
# 1519830536855773186  While I am missing a lot of people who couldn'...
# 1519830688760877056      Found my ex at @pycon https://t.co/ajoAY0T5Yl
# 1519831135164899330  Opening up at PyCon 2022. @AccordionGuy at the...
# 1519831372138835969  It’s looking busy at @pycon! Come by to see a ...
# 1519832200702619648                  @hjwp you gonna be at PyCon 2022?
# 1519832577959514114                 @JavaFXpert @pycon @qiskit Yeah !!
# 1519832867898937345      @trixtur I'm at @pycon in SLC. Where are you?
# 1519834573076541440  @calvinhp Holy shit. I didn't even realize PyC...

# %%
# Full-text search!
df.filter(["author", "content"]).es_match("stickers")
# Out:
#                              author  \
# 1519064219324325888        davidism
# 1518302070398504961        iamukasa
# 1517888164496560128           pgag_
# 1517587167064870917    dennyperez18
# 1518999040884543490        chrisjrn
# 1519802686702465026   reuvenmlerner
# 1519758027481567238        NumFOCUS
# 1519732427500843009    DeepgramDevs
# 1519726998699986947   GlennLehman10
# 1519724687890128899      treyhunner
# 1519718469276606464      floopybits
# 1519566936648081409      valerybriz
# 1519565947815686144    WillingCarol
# 1519487733877534720  zitterbewegung
# 1519410562551062528   reuvenmlerner
#
#                                                                                                                                                                                                                                                                                                                              content
# 1519064219324325888                                                                                                                      Can't wait to be at PyCon! Just a few more days. I'm going to be running sprints for Flask, Jinja, Click, etc., and running some open spaces, like always! Find me for cool Flask stickers.
# 1518302070398504961                                                                                                                                                   Willing to exchange card tricks for laptop stickers at PyCon.....and before you ask stickers is a game of diversity can't fill the PC with just the event swag
# 1517888164496560128                                                                                                                                                                                                  @dennyperez18 @pycon @ALAColombia @octogatos @GitHubCommunity I'm going to be chasing you for these stickers. 😉
# 1517587167064870917  Getting ready for @pycon !🐍💜🚀\n\nIt'll be my first conference in person and trip since Oct, 2019 and I'm kind of nervous but also excited!😃\n\nWould you like to have a GitHub swag or stickers?🐙\n\nSee you at #PyConUS2022 in Salt Lake City, Utah.\n\nthx @ALAColombia 💜🤗\n\n#PyCon🐍 https://t.co/qpyHbIUfL0
# 1518999040884543490                                                                                                                    Hello friends! I'll be at #pyconus (#pyconus2022) from tomorrow afternoon through Monday, and I'll have @pantsbuild stickers to adorn your laptop. If you'll be there this week, come say hi?
# 1519802686702465026                                                                                                                                                            All set for the start of @pycon US in Salt Lake City! Stop by for shirts, stickers, and a raffle for free copies of my books! https://t.co/PC7vJdGfz2
# 1519758027481567238                                                                                                                            @floopybits @pycon Thanks for the excitement around our project logo stickers! We love them, too 😊. And you can order them through the NumFOCUS online shop: https://t.co/qUtFWuF3L0.
# 1519732427500843009                               ✅ PyCon booth set up\n✅ T-shirts and stickers out\n✅ Masked up\n\nCome say 👋🏾 hi to Brian Barrow @the_BrianB  and Tonya Sims  @tonyasims at our #pycon2022 Deepgram booth location 529 and try our speech-to-text tech, with a chance to win a cool prize. https://t.co/xktM3P02Pd
# 1519726998699986947                                                                                                                                                                                                                            @treyhunner @pycon @PythonMorsels I looking for you ... need stickers for my laptop!!
# 1519724687890128899                                                   Python friends &amp; not-yet-friends: I'm at @pycon today and tomorrow. 🐍\n\nPlease say hi if you see me. 👋 I'd love to chat with you while I'm here. 💖\n\nI have @PythonMorsels stickers for you. 🐍🍪 Ask me for some!\n\n#PyConUS2022 https://t.co/b6xprUXNJz
# 1519718469276606464                                                                                                                                                                                                                                                     @NumFOCUS @pycon guys any way we can order stickers online 😄
# 1519566936648081409                                                                                                                                                                       @cecivieira @SaltLakeCityUT @pycon @pyconcharlas Ohhh I love tulips in this time of the year in US\nHave a great pycon!\nBring stickers! 😉
# 1519565947815686144                             I have a new friend, PyDuck, a gift from the amazing @georgically1 (who also did the PyCon graphics). I'm so excited to introduce my @noteable_io team to the Python community too. I have some cool Dexy, our Noteable squirrel, stickers too. #PyConUS2022 https://t.co/N34wtLy0FP
# 1519487733877534720                                                                                                                                   @pycon Day one. New stickers:  https://t.co/ePD2RFvL0u made by @Anyscale from @2twitme and https://t.co/gPPyz7MTqS Pyre made by @Meta (FB Open Source) https://t.co/z0CfOjTmvY
# 1519410562551062528                                                                                                                                                                                          T shirts and stickers, almost ready for distribution at my @pycon booth. Very happy to be here. https://t.co/nUgwpGnkcA
#
# [15 rows x 2 columns]

# %% [markdown]
# ## Aggregations with Eland
#
# Eland supports many Pandas aggregations including min, mean, median, max, var, std, count, nunique, sum, and mad.
#
# Aggregations are mapped to Elasticsearch aggs and then unpacked into a Pandas DataFrame or Series.
#
# Read more about [`eland.DataFrame.agg()`](https://eland.readthedocs.io/en/latest/reference/api/eland.DataFrame.agg.html#eland.DataFrame.agg)

# %%
df[["likes", "retweets", "replies"]].agg(["min", "mean", "median", "max", "var", "std"])
# Out:
#               likes    retweets    replies
# min        0.000000    0.000000   0.000000
# mean       8.811289    1.048863   0.698399
# median     2.000000    0.000000   0.000000
# max     1066.000000  100.000000  72.000000
# var     1586.828399   16.695464   8.380976
# std       39.860203    4.088592   2.896822

# %%
df.language.value_counts()
# Out:
# en     1032
# es       50
# und      45
# ja       27
# pt       14
# pl        4
# ca        3
# in        3
# fr        2
# it        2
# Name: language, dtype: int64

# %% [markdown]
# ## Machine Learning
#
# Since this is a read-only cluster you can't upload your own models
# however I can show you how an existing model on the cluster was
# trained.
#
# More information on [Machine Learning in Eland](https://eland.readthedocs.io/en/latest/reference/ml.html)
#
# For this Machine Learning demo we use the scikit-learn [`wine` classifier dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html)
# and a [`DecisionTreeClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) model. Full list of supported model types available in the Machine Learning docs for Eland.
#
# ### Import Scikit-Learn and Train Model Locally
#
# ```python
# >>> from sklearn import datasets
# >>> from sklearn.tree import DecisionTreeClassifier
#
# >>> digits = datasets.load_wine()
# >>> print("Feature Names:", digits.feature_names)
# Feature Names: ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
#
# >>> print("Data example:", digits.data[0])
# Data example: [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
#
# # Save 10, 80, and 140 for testing our model
# >>> data = [x for i, x in enumerate(digits.data) if i not in (10, 80, 140)]
# >>> target = [x for i, x in enumerate(digits.target) if i not in (10, 80, 140)]
#
# # Fit the other data to a DecisionTreeClassifier
# >>> sk_classifier = DecisionTreeClassifier()
# >>> sk_classifier.fit(data, target)
# ```
#
# ### Test the Locally Trained Model
#
# ```python
# >>> print(sk_classifier.predict(digits.data[[10, 80, 140]]))
# [0 1 2]
#
# >>> print(digits.target[[10, 80, 140]])
# [0 1 2]
# ```
#
# ### Serialize the Scikit-Learn Model into Elasticsearch
#
# ```python
# >>> from eland.ml import MLModel
#
# >>> es_classifier = MLModel.import_model(
# ...     es_client=es,
# ...     model_id="wine-classifier",
# ...     model=sk_classifier,
# ...     feature_names=digits.feature_names,
# ...     es_if_exists="replace"
# >>> )
# ```
#
# ### Run the Model in Elasticsearch!
#
# ```python
# >>> print(es_classifier.predict(digits.data[[10, 80, 140]]))
# [0 1 2]
#
# # Tada!
# ```

# %% [markdown]
# ## What's Coming Next?
#
# Eland is open sourced on GitHub and if [you're interested in helping build new features](https://github.com/elastic/eland/issues?q=is%3Aissue+is%3Aopen+label%3A%22good+first+issue%22) we'd love to have you!
#
# Here's a list of features that are coming soon to Eland:
#
# #### – Native [Geo-spatial Queries](https://www.elastic.co/guide/en/elasticsearch/reference/current/geo-queries.html) and Integration with [Geopandas](https://geopandas.org/)
# #### – Aggregate and Visualize Time-Series Data
# #### – More natural language processing model support
